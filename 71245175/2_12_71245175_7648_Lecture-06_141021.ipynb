# %%
goals = {
    "Brazil" : { 
        "Croatia" : 3,
        "Mexico" : 0,
        "Cameroon" : 4,
        "Chile" : 1,
        "Colombia" : 2,
        "Germany" : 1,
        "Netherlands" : 0 },
    "Croatia" : { 
        "Brazil" : 1,
        "Mexico" : 1,
        "Cameroon" : 4 },
    "Mexico" : { 
        "Brazil" : 0,
        "Croatia" : 3,
        "Cameroon" : 1,
        "Netherlands" : 1 },
    "Cameroon" : { 
        "Brazil" : 1,
        "Croatia" : 0,
        "Mexico" : 0 },

    "Netherlands" : { 
        "Chile" : 2,
        "Spain" : 5,
        "Australia" : 3,
        "Mexico" : 2,
        "Costa Rica" : 0,
        "Argentina" : 0,
        "Brazil" : 3 },
    "Chile" : { 
        "Netherlands" : 0,
        "Spain" : 2,
        "Australia" : 3,
        "Brazil" : 1 },
    "Spain" : { 
        "Netherlands" : 1,
        "Chile" : 0,
        "Australia" : 3 },
    "Australia" : { 
        "Netherlands" : 2,
        "Chile" : 1,
        "Spain" : 0 },

    "Colombia" : { 
        "Greece" : 3,
        "Ivory Coast" : 2,
        "Japan" : 4,
        "Uruguay" : 2,
        "Brazil" : 1 },
    "Greece" : { 
        "Colombia" : 0,
        "Ivory Coast" : 2,
        "Japan" : 0,
        "Costa Rica" : 1 },
    "Ivory Coast" : { 
        "Colombia" : 1,
        "Greece" : 1,
        "Japan" : 2 },
    "Japan" : { 
        "Colombia" : 1,
        "Greece" : 0,
        "Ivory Coast" : 1 },

    "Costa Rica" : { 
        "Uruguay" : 3,
        "Italy" : 1,
        "England" : 0,
        "Greece" : 1,
        "Netherlands" : 0 },
    "Uruguay" : { 
        "Costa Rica" : 1,
        "Italy" : 1,
        "England" : 2,
        "Colombia" : 0 },
    "Italy" : { 
        "Costa Rica" : 0,
        "Uruguay" : 0,
        "England" : 2 },
    "England" : { 
        "Costa Rica" : 0,
        "Uruguay" : 1,
        "Italy" : 1 },

    "France" : { 
        "Switzerland" : 5,
        "Ecuador" : 0,
        "Honduras" : 3,
        "Nigeria" : 2,
        "Germany" : 0 },
    "Switzerland" : { 
        "France" : 2,
        "Ecuador" : 2,
        "Honduras" : 3,
        "Argentina" : 0 },
    "Ecuador" : { 
        "France" : 0,
        "Switzerland" : 1,
        "Honduras" : 2 },
    "Honduras" : { 
        "France" : 0,
        "Switzerland" : 0,
        "Ecuador" : 1 },

    "Argentina" : { 
        "Nigeria" : 3,
        "Bosnia-Herzegovina" : 2,
        "Iran" : 1,
        "Switzerland" : 1,
        "Belgium" : 1,
        "Netherlands" : 0,
        "Germany" : 0 },
    "Nigeria" : { 
        "Argentina" : 2,
        "Bosnia-Herzegovina" : 1,
        "Iran" : 0,
        "France" : 0 },
    "Bosnia-Herzegovina" : { 
        "Argentina" : 1,
        "Nigeria" : 0,
        "Iran" : 3 },
    "Iran" : { 
        "Argentina" : 0,
        "Nigeria" : 0,
        "Bosnia-Herzegovina" : 1 },

    "Germany" : { 
        "United States" : 1,
        "Portugal" : 4,
        "Ghana" : 2,
        "Algeria" : 2,
        "France" : 1,
        "Brazil" : 7,
        "Argentina" : 1 },
    "United States" : { 
        "Germany" : 0,
        "Portugal" : 2,
        "Ghana" : 2,
        "Belgium" : 1 },
    "Portugal" : { 
        "Germany" : 0,
        "United States" : 2,
        "Ghana" : 2 },
    "Ghana" : { 
        "Germany" : 2,
        "United States" : 1,
        "Portugal" : 1 },

    "Belgium" : { 
        "Algeria" : 2,
        "Russia" : 1,
        "South Korea" : 1,
        "United States" : 2,
        "Argentina" : 0 },
    "Algeria" : { 
        "Belgium" : 1,
        "Russia" : 1,
        "South Korea" : 4,
        "Germany" : 1 },
    "Russia" : { 
        "Belgium" : 0,
        "Algeria" : 1,
        "South Korea" : 1 },
    "South Korea" : { 
        "Belgium" : 0,
        "Algeria" : 2,
        "Russia" : 1 }
}

for x in goals.keys():
    print x
    a = 0
    for y in goals[x].values():
        a = a + y 
    print a
# Out:
# Brazil
# 11
# Netherlands
# 15
# Italy
# 2
# Colombia
# 12
# Costa Rica
# 5
# France
# 10
# United States
# 5
# Croatia
# 6
# Ivory Coast
# 4
# Iran
# 1
# Switzerland
# 7
# Honduras
# 1
# Argentina
# 8
# Cameroon
# 1
# Nigeria
# 3
# Ecuador
# 3
# Ghana
# 4
# Australia
# 3
# England
# 2
# Algeria
# 7
# Portugal
# 4
# Mexico
# 5
# Uruguay
# 4
# Russia
# 2
# Germany
# 18
# Chile
# 6
# Greece
# 3
# Belgium
# 6
# Japan
# 2
# South Korea
# 3
# Bosnia-Herzegovina
# 4
# Spain
# 4
