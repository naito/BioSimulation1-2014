# %% [markdown]
# # 最終試験（２）

# %%
import imp
try:
    imp.find_module("ecell")
except ImportError:
    import sys
    sys.path.append("/opt/local/lib/python2.7/site-packages")
    sys.path.append("/opt/local/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages")

# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %install_ext https://raw.githubusercontent.com/naito/ecell3-ipython/master/extensions/ecell3.py
# %load_ext ecell3
# Out:
# Installed ecell3.py. To use it, type:
#   %load_ext ecell3

# %% [markdown]
# ### モデルファイルの読み込み

# %%
loadModel("Lec-14.eml")

# %% [markdown]
# ## 問題２

# %% [markdown]
# * 時刻 _t_ = 0 での _S_ の値（`Value`）を、1.1 に設定し、時刻 _t_ = 50 までシミュレーションを実行し、_X_ の値（`Value`）をプロットしなさい。

# %%
# 解答欄
target_SystemPath = '/'
Target_Properties = { 'Variable':'Value', 'Process':'Activity' }
Logger_dict = {}

for E_type, p in Target_Properties.items():
    for E in getEntityList( E_type, target_SystemPath ):
        FullPN = ':'.join( ( E_type, target_SystemPath, E, p ) )
        if FullPN != 'Variable:/:SIZE:Value':
            Logger_dict[ FullPN ] = createLoggerStub( FullPN )
        
for L in Logger_dict.values():
    L.create()

S1 = createEntityStub( 'Variable:/:S' )
S1.getPropertyList()
S1['Value'] = 1.1
run( 50 )

Data_dict = {}
for FullPN, Logger in Logger_dict.items():
    Data_dict[ FullPN ] = np.array( Logger.getData( 0, 50, 0.1 ) )[ :, :2 ]

Variable_FullPN_list = [ FullPN for FullPN in Data_dict.keys() if FullPN.split(':')[ 0 ] == 'Variable' ]
Process_FullPN_list = [ FullPN for FullPN in Data_dict.keys() if FullPN.split(':')[ 0 ] == 'Process' ]

plt.figure()
for FullPN, d in Data_dict.items():
    if FullPN in Variable_FullPN_list:
        plt.figure()
        plt.plot( d[ :, 0 ], d[ :, 1 ], label = FullPN.split(':')[ 2 ] )
        plt.legend( loc = 'lower right' )

# %% [markdown]
# * 問題１の _X_ の値の違いを説明しなさい。１行の簡単な説明でかまいません。

# %% [markdown]
# 解答欄
# 問題１のxは減少したのに対して、Sを1.1にすることにより、Xは増加した。

# %% [markdown]
# #### FinalExam-3 に進んでください。

# %% [markdown]
# ### 問題２Ｂ

# %% [markdown]
# * 問題３が難しくて歯が立たないと感じたら、こちらを解いてもいいです。問題３よりはやや易しいはずです。
# * 元のモデル（_S_ の初期値 = 1.0 ）と、問題２で変更したモデル（_S_ の初期値 = 1.1 ）の違いを、４つの `Variable` の `Value`、４つの `Process` の `Activity` （反応速度）を調べて説明しなさい。
# * 下の解答欄１にコードを、解答欄２に説明を、それぞれ書きなさい。

# %%
# 解答欄１
target_SystemPath = '/'
Target_Properties = { 'Variable':'Value', 'Process':'Activity' }
Logger_dict = {}

for E_type, p in Target_Properties.items():
    for E in getEntityList( E_type, target_SystemPath ):
        FullPN = ':'.join( ( E_type, target_SystemPath, E, p ) )
        if FullPN != 'Variable:/:SIZE:Value':
            Logger_dict[ FullPN ] = createLoggerStub( FullPN )
        
for L in Logger_dict.values():
    L.create()

S1 = createEntityStub( 'Variable:/:S' )
S1.getPropertyList()
S1['Value'] = 1.1
run( 50 )

Data_dict = {}
for FullPN, Logger in Logger_dict.items():
    Data_dict[ FullPN ] = np.array( Logger.getData( 0, 50, 0.1 ) )[ :, :2 ]

Variable_FullPN_list = [ FullPN for FullPN in Data_dict.keys() if FullPN.split(':')[ 0 ] == 'Variable' ]
Process_FullPN_list = [ FullPN for FullPN in Data_dict.keys() if FullPN.split(':')[ 0 ] == 'Process' ]

plt.figure()
for FullPN, d in Data_dict.items():
    if FullPN in Variable_FullPN_list:
        plt.plot( d[ :, 0 ], d[ :, 1 ], label = FullPN.split(':')[ 2 ] )
        plt.legend( loc = 'upper right' )
        
plt.figure()        
for FullPN, d in Data_dict.items():
    if FullPN in Process_FullPN_list:
        plt.plot( d[ :, 0 ], d[ :, 1 ], label = FullPN.split(':')[ 2 ] )
        plt.legend( loc = 'upper right' )
      
S1['Value'] = 1.0

Data_dict2 = {}
for FullPN, Logger in Logger_dict.items():
    Data_dict2[ FullPN ] = np.array( Logger.getData( 0, 50, 0.1 ) )[ :, :2 ]

Variable_FullPN_list = [ FullPN for FullPN in Data_dict2.keys() if FullPN.split(':')[ 0 ] == 'Variable' ]
Process_FullPN_list = [ FullPN for FullPN in Data_dict2.keys() if FullPN.split(':')[ 0 ] == 'Process' ]

plt.figure()
for FullPN, d in Data_dict2.items():
    if FullPN in Variable_FullPN_list:
        plt.plot( d[ :, 0 ], d[ :, 1 ], label = FullPN.split(':')[ 2 ] )

# %% [markdown]
# 解答欄２
